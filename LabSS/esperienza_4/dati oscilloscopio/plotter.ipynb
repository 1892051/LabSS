# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
j=7

df = pd.read_csv("scope_{}.csv".format(j))

v1 = []
for i in df["1"][1:]:
    v1.append(float(i))
v1 = np.array(v1)

v2 = []
for i in df["2"][1:]:
    v2.append(float(i))
v2 = np.array(v2)

x =[]
for i in df["x-axis"][1:]:
    x.append(float(i))
x = np.array(x)

plt.plot(x, v1, color="yellow", label="ingresso 1")
plt.plot(x, v2, color="green", label="ingresso 2")
plt.xlabel("Tempo t (s)")
plt.ylabel("V (V)")
plt.grid()
plt.legend()
plt.title("Vista oscilloscopio")
plt.savefig("scope_{}.png".format(j), dpi=150)

# %%
# Out:
# Text(0.5, 1.0, 'Vista oscilloscopio')
