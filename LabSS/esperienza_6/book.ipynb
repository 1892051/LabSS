# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

# %% [markdown]
# # Parte 1: Risposta NOT

# %%
v_in = np.hstack((np.array([4.68,254.6,576,761,881])*10**-3,np.array([1.005,1.006,1.006,1.215,1.530,2.010,2.506,3.016,3.503,4.001,4.527,5]))) #V
v_out = np.array([4.292,4.251,4.180,4.052,3.848,2.858,2.38,1.15,0.242,0.136,0.136,0.136,0.136,0.136,0.136,0.136,0.136]) #V

# %%
plt.scatter(v_in,v_out)
plt.xlabel("$V_{in}$ (V)")
plt.ylabel("$V_{out}$ (V)")
plt.title("$V_{out}$ VS $V_{in}$")
plt.grid()
plt.savefig("Not.png", dpi=300)
